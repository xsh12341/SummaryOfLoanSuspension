# %% [markdown]
# <a href="https://colab.research.google.com/github/xsh12341/SummaryOfLoanSuspension/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $\Huge{\text{google colab}}$
#
# ---
#
#
# $$\Large{\text{google colab}} = \text{jupyter notebook based google driver}$$

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title

from matplotlib import pyplot as plt
import matplotlib.image as mpimg

# 替换下面的路径为你的图片在Drive中的实际路径
img_path = '/content/drive/MyDrive/colabjupyter.png'

img = mpimg.imread(img_path)

# 使用 figsize 调整图像大小，例如，设置宽度为10英寸，高度为根据图片比例自动调整
plt.figure(figsize=(10, img.shape[0]/img.shape[1]*10))  # 这里10是宽度，高度按图片比例自动调整
plt.imshow(img)
plt.axis('off') # 不显示坐标轴
plt.show()

# %%
#大部分用的库都会给装好
# !pip install torch torchvision

# %% [markdown]
# # **GPU与TPU**
#
# <ul>
#   <li><h2>GPU:擅长处理大量并行计算任务,适合于需要大规模数值计算的应用</h2></li>
#   <li><h2>TPU:专门为深度学习优化的处理器，特别适用于TensorFlow框架下的计算任务</h2></li>
# </ul>
#
#
#
# ---
#
#
# <ul>
#   <li><h2>代码执行程序</h2></li>
#   <li><h2>更改运行时的类型</h2></li>
# </ul>

# %% [markdown]
# # **左侧的工具栏**
#
# <ul>
#   <li><h2>目录</h2></li>
#   <li><h2>查找与替换</h2></li>
#   <li><h2>变量</h2></li>
#   <li><h2>secret</h2></li>
#   <li><h2>文件</h2></li>
#   <li><h2>代码段</h2></li>
#   <li><h2>命令面板</h2></li>
#
# </ul>

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x='mean(Miles_per_Gallon)',
  y='Origin',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # **导入与导出**
#
# <ul>
#   <li><h2>google driver</h2></li>
#   <li><h2>github</h2></li>
#   <li><h2>由于很容易分享，因此也很容易获得别人的分享<a href="https://www.kaggle.com/">Kaggle</a></strong></h2></li>
#
# </ul>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title
# 替换下面的路径为你的图片在Drive中的实际路径
img_path = '/content/drive/MyDrive/kaggle.bmp'

img = mpimg.imread(img_path)

# 使用 figsize 调整图像大小，例如，设置宽度为10英寸，高度为根据图片比例自动调整
plt.figure(figsize=(10, img.shape[0]/img.shape[1]*10))  # 这里10是宽度，高度按图片比例自动调整
plt.imshow(img)
plt.axis('off') # 不显示坐标轴
plt.show()

# %% [markdown]
# # **交互式表格**

# %%
from google.colab import data_table
from vega_datasets import data

cars = data.cars()
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...

# %%
from google.colab import data_table
from vega_datasets import data

data_table.enable_dataframe_formatter()
cars = data.cars()
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...

# %% [markdown]
# # **执行历史**
#
#
# <ul>
#   <li><h2>视图</h2></li>
#   <li><h2>代码执行历史</h2></li>
# </ul>

# %%
# %%html
# <marquee style='width: 40%; color: blue; font-size: 24px;'><b>Colaboratory</b></marquee>
# Out:
# <marquee style='width: 40%; color: blue; font-size: 24px;'><b>Colaboratory</b></marquee>

# %% [markdown]
# # **缺点**
#
#
# <ul>
#   <li><h2>资源量是受限制的，所有 Colab 运行时都会在一段时间（据说是12h左右）后重置</h2></li>
#   <li><h2>GPU、TPU的性能不稳定</h2></li>
#   <li><h2>免费用户可以获取15G的空间</h2></li>
# </ul>

# %% [markdown]
# # **微软的生态系统**
