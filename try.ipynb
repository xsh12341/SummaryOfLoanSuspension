# %% [markdown]
# <a href="https://colab.research.google.com/github/xsh12341/SummaryOfLoanSuspension/blob/main/try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $\Huge{\text{google colab}}$
#
#
#
# ---
# $$\Large{\text{google colab}} = \text{jupyter notebook based google driver}$$
#
#
# ![图片1.png](data:image/png;base64,...)

# %%
#大部分用的库都会给装好
# !pip install torch torchvision

# %% [markdown]
# # **导入与导出**
#
# <ul>
#   <li><h2>google driver</h2></li>
#   <li><h2>github</h2></li>
# </ul>

# %% [markdown]
# # **左侧的工具栏**
#
#
# 1.   目录
# 2.   查找与替换
# 3.   变量
# 4.   secret
# 5.   文件
# 6.   代码段
# 7.   命令面板

# %% [markdown]
# # **GPU与TPU**
#
#
# *   代码执行程序
# *   更改运行时的类型

# %% [markdown]
# # **交互式表格**

# %%
from google.colab import data_table
from vega_datasets import data

cars = data.cars()
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...

# %%
from google.colab import data_table
from vega_datasets import data

data_table.enable_dataframe_formatter()
cars = data.cars()
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...

# %% [markdown]
# # **执行历史**
#
#
# *   视图
# *   代码执行历史

# %%
# %%html
# <marquee style='width: 30%; color: blue;'><b>Colaboratory</b></marquee>
# Out:
# <marquee style='width: 30%; color: blue;'><b>Colaboratory</b></marquee>

# %% [markdown]
# # **缺点**
#
#
# *   资源量是受限制的，所有 Colab 运行时都会在一段时间后重置
# *   GPU、TPU的性能不稳定
# *   免费用户可以获取15G的空间
# *   列表项

# %% [markdown]
# # **微软的生态系统**
